# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/bestsellers with categories.csv')

# %% [markdown]
# * Name - 제목
# * Author - 저자
# * User Rating - 사용자평가
# * Review - 리뷰
# * Price - 가격
# * Year - 연도
# * Genre - 유형

# %%
df.head(3)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
#
#    Reviews  Price  Year        Genre
# 0    17350      8  2016  Non Fiction
# 1     2052     22  2011      Fiction
# 2    18979     15  2018  Non Fiction

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
df[df.Price == 0].sort_values('Author')
# Out:
#                                                   Name  \
# 219                                  Little Blue Truck
# 358              The Constitution of the United States
# 505                              To Kill a Mockingbird
# 506                              To Kill a Mockingbird
# 507                              To Kill a Mockingbird
# 508                              To Kill a Mockingbird
# 42          Cabin Fever (Diary of a Wimpy Kid, Book 6)
# 71             Diary of a Wimpy Kid: Hard Luck, Book 8
# 381                                        The Getaway
# 116                        Frozen (Little Golden Book)
# 193                               JOURNEY TO THE ICE P
# 461  The Short Second Life of Bree Tanner: An Eclip...
#
#                                Author  User Rating  Reviews  Price  Year  \
# 219                    Alice Schertle          4.9     1884      0  2014
# 358  Delegates of the Constitutional
#           4.8     2774      0  2016
# ...

# %%
df[df.Name == 'To Kill a Mockingbird']
# Out:
#                       Name      Author  User Rating  Reviews  Price  Year  \
# 505  To Kill a Mockingbird  Harper Lee          4.8    26234      0  2013
# 506  To Kill a Mockingbird  Harper Lee          4.8    26234      0  2014
# 507  To Kill a Mockingbird  Harper Lee          4.8    26234      0  2015
# 508  To Kill a Mockingbird  Harper Lee          4.8    26234      0  2016
# 509  To Kill a Mockingbird  Harper Lee          4.8    26234      7  2019
#
#        Genre
# 505  Fiction
# 506  Fiction
# 507  Fiction
# 508  Fiction
# 509  Fiction

# %%
df[df.Name == 'Little Blue Truck']
# Out:
#                   Name          Author  User Rating  Reviews  Price  Year  \
# 219  Little Blue Truck  Alice Schertle          4.9     1884      0  2014
#
#        Genre
# 219  Fiction

# %%
df[df.Name == 'The Constitution of the United States']
# Out:
#                                       Name                            Author  \
# 358  The Constitution of the United States  Delegates of the Constitutional
#
#
#      User Rating  Reviews  Price  Year        Genre
# 358          4.8     2774      0  2016  Non Fiction

# %%
df[df.Name == 'Diary of a Wimpy Kid: Hard Luck, Book 8']
# Out:
#                                        Name       Author  User Rating  \
# 71  Diary of a Wimpy Kid: Hard Luck, Book 8  Jeff Kinney          4.8
#
#     Reviews  Price  Year    Genre
# 71     6812      0  2013  Fiction

# %%
df.loc[df.Name == 'To Kill a Mockingbird','Price'] = 7

# %%
df[df.Name == 'To Kill a Mockingbird']
# Out:
#                       Name      Author  User Rating  Reviews  Price  Year  \
# 505  To Kill a Mockingbird  Harper Lee          4.8    26234      7  2013
# 506  To Kill a Mockingbird  Harper Lee          4.8    26234      7  2014
# 507  To Kill a Mockingbird  Harper Lee          4.8    26234      7  2015
# 508  To Kill a Mockingbird  Harper Lee          4.8    26234      7  2016
# 509  To Kill a Mockingbird  Harper Lee          4.8    26234      7  2019
#
#        Genre
# 505  Fiction
# 506  Fiction
# 507  Fiction
# 508  Fiction
# 509  Fiction

# %%
df[df.Author.isin(['Alice Schertle','Jeff Kinney','RH Disney','Stephenie Meyer'])].sort_values('Author')
# Out:
#                                                   Name           Author  \
# 219                                  Little Blue Truck   Alice Schertle
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
# 42          Cabin Fever (Diary of a Wimpy Kid, Book 6)      Jeff Kinney
# 71             Diary of a Wimpy Kid: Hard Luck, Book 8      Jeff Kinney
# 72       Diary of a Wimpy Kid: The Last Straw (Book 3)      Jeff Kinney
# 73                 Diary of a Wimpy Kid: The Long Haul      Jeff Kinney
# 80   Dog Days (Diary of a Wimpy Kid, Book 4) (Volum...      Jeff Kinney
# 88              Double Down (Diary of a Wimpy Kid #11)      Jeff Kinney
# 474      The Ugly Truth (Diary of a Wimpy Kid, Book 5)      Jeff Kinney
# 468     The Third Wheel (Diary of a Wimpy Kid, Book 7)      Jeff Kinney
# 435        The Meltdown (Diary of a Wimpy Kid Book 13)      Jeff Kinney
# 381                                        The Getaway      Jeff Kinney
# ...

# %%
df_2014 = df[df.Year == 2014]

# %%
df_2014[df_2014.Price > 0].groupby('Genre').mean()
# Out:
#              User Rating       Reviews      Price    Year
# Genre
# Fiction         4.619231  21369.192308  11.615385  2014.0
# Non Fiction     4.609524  10994.952381  20.809524  2014.0

# %%
df.loc[df.Name == 'Little Blue Truck','Price'] = 11
df.loc[df.Name == 'Frozen (Little Golden Book)','Price'] = 11
df.loc[df.Name == 'JOURNEY TO THE ICE P','Price'] = 11

# %%
df[df.Price == 0].sort_values('Author')
# Out:
#                                                   Name  \
# 358              The Constitution of the United States
# 42          Cabin Fever (Diary of a Wimpy Kid, Book 6)
# 71             Diary of a Wimpy Kid: Hard Luck, Book 8
# 381                                        The Getaway
# 461  The Short Second Life of Bree Tanner: An Eclip...
#
#                                Author  User Rating  Reviews  Price  Year  \
# 358  Delegates of the Constitutional
#           4.8     2774      0  2016
# 42                        Jeff Kinney          4.8     4505      0  2011
# 71                        Jeff Kinney          4.8     6812      0  2013
# 381                       Jeff Kinney          4.8     5836      0  2017
# 461                   Stephenie Meyer          4.6     2122      0  2010
#
#            Genre
# 358  Non Fiction
# 42       Fiction
# 71       Fiction
# 381      Fiction
# 461      Fiction
